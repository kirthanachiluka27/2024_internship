# %% [markdown]
# # Movie recommendation system hackathon

# %%
import csv
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv(r"C:\Users\KINGS\Downloads\movie_data\movies.csv")

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
movies['genres'].unique()
# Out:
# array(['Adventure|Animation|Children|Comedy|Fantasy',
#        'Adventure|Children|Fantasy', 'Comedy|Romance',
#        'Comedy|Drama|Romance', 'Comedy', 'Action|Crime|Thriller',
#        'Adventure|Children', 'Action', 'Action|Adventure|Thriller',
#        'Comedy|Horror', 'Adventure|Animation|Children', 'Drama',
#        'Action|Adventure|Romance', 'Crime|Drama', 'Drama|Romance',
#        'Action|Comedy|Crime|Drama|Thriller', 'Comedy|Crime|Thriller',
#        'Crime|Drama|Horror|Mystery|Thriller', 'Drama|Sci-Fi',
#        'Children|Drama', 'Adventure|Drama|Fantasy|Mystery|Sci-Fi',
#        'Mystery|Sci-Fi|Thriller', 'Children|Comedy', 'Drama|War',
#        'Action|Crime|Drama', 'Action|Adventure|Fantasy',
#        'Comedy|Drama|Thriller', 'Mystery|Thriller',
#        'Animation|Children|Drama|Musical|Romance',
#        'Crime|Mystery|Thriller', 'Adventure|Drama', 'Drama|Thriller',
#        'Comedy|Crime', 'Action|Sci-Fi|Thriller',
# ...

# %%
movies.shape
# Out:
# (9742, 3)

# %%
ratings=pd.read_csv(r"C:\Users\KINGS\Downloads\movie_data\ratings.csv")

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
ratings.max()
# Out:
# userId       6.100000e+02
# movieId      1.936090e+05
# rating       5.000000e+00
# timestamp    1.537799e+09
# dtype: float64

# %%
ratings.min()
# Out:
# userId               1.0
# movieId              1.0
# rating               0.5
# timestamp    828124615.0
# dtype: float64

# %%
ratings.std()
# Out:
# userId       1.826185e+02
# movieId      3.553099e+04
# rating       1.042529e+00
# timestamp    2.162610e+08
# dtype: float64

# %%
data=pd.merge(movies,ratings,on='movieId')
data.head(15)
# Out:
#     movieId             title                                       genres  \
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 10        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
data['movieId'].unique()
# Out:
# array([     1,      2,      3, ..., 193585, 193587, 193609], dtype=int64)

# %%
data.groupby('title')['rating'].max().sort_values(ascending=False).head()
# Out:
# title
# Harry Potter and the Order of the Phoenix (2007)    5.0
# Ever After: A Cinderella Story (1998)               5.0
# Mystery Science Theater 3000: The Movie (1996)      5.0
# Tremors (1990)                                      5.0
# Mystery Men (1999)                                  5.0
# Name: rating, dtype: float64

# %%
data.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Forrest Gump (1994)                 329
# Shawshank Redemption, The (1994)    317
# Pulp Fiction (1994)                 307
# Silence of the Lambs, The (1991)    279
# Matrix, The (1999)                  278
# Name: rating, dtype: int64

# %%
tags=pd.read_csv(r"C:\Users\KINGS\Downloads\movie_data\tags.csv")

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %%
dt=pd.merge(data,tags,on='movieId')

# %%
dt
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
d=pd.DataFrame(dt.groupby("title")['rating'].max())

# %%
d["num of ratings"]=data.groupby('title').count()['rating']
d.head(20)
# Out:
#                                                     rating  num of ratings
# title
# (500) Days of Summer (2009)                            5.0              42
# ...And Justice for All (1979)                          4.0               3
# 10 Cloverfield Lane (2016)                             5.0              14
# 10 Things I Hate About You (1999)                      5.0              54
# 101 Dalmatians (1996)                                  5.0              47
# 101 Dalmatians (One Hundred and One Dalmatians)...     5.0              44
# 11'09"01 - September 11 (2002)                         4.0               2
# 12 Angry Men (1957)                                    5.0              57
# 127 Hours (2010)                                       5.0              18
# 13 Going on 30 (2004)                                  5.0              21
# 2001: A Space Odyssey (1968)                           5.0             109
# ...

# %%
ratings['rating'].mean()
# Out:
# 3.501556983616962

# %%
tags
# Out:
#       userId  movieId               tag
# 0          2    60756             funny
# 1          2    60756   Highly quotable
# 2          2    60756      will ferrell
# 3          2    89774      Boxing story
# 4          2    89774               MMA
# ...      ...      ...               ...
# 3678     606     7382         for katie
# 3679     606     7936           austere
# 3680     610     3265            gun fu
# 3681     610     3265  heroic bloodshed
# 3682     610   168248  Heroic Bloodshed
#
# [3683 rows x 3 columns]

# %%
tags['tag'].unique()
# Out:
# array(['funny', 'Highly quotable', 'will ferrell', ..., 'gun fu',
#        'heroic bloodshed', 'Heroic Bloodshed'], dtype=object)

# %%
tags['tag']=='alternate universe'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3678    False
# 3679    False
# 3680    False
# 3681    False
# 3682    False
# Name: tag, Length: 3683, dtype: bool

# %%
tags['tag']=='karate'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3678    False
# 3679    False
# 3680    False
# 3681    False
# 3682    False
# Name: tag, Length: 3683, dtype: bool

# %%
data['title']=='Terminator 2'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100831    False
# 100832    False
# 100833    False
# 100834    False
# 100835    False
# Name: title, Length: 100836, dtype: bool

# %%
d["num of ratings"]=data.groupby('title').count()['rating']
d
# Out:
#                                    rating  num of ratings
# title
# (500) Days of Summer (2009)           5.0              42
# ...And Justice for All (1979)         4.0               3
# 10 Cloverfield Lane (2016)            5.0              14
# 10 Things I Hate About You (1999)     5.0              54
# 101 Dalmatians (1996)                 5.0              47
# ...                                   ...             ...
# Zero Dark Thirty (2012)               5.0              14
# Zombieland (2009)                     5.0              53
# Zoolander (2001)                      5.0              54
# Zulu (1964)                           5.0               4
# eXistenZ (1999)                       5.0              22
#
# [1554 rows x 2 columns]

# %%
#pd.DataFrame(d.groupby['num of ratings']>50)
#DT=pd.DataFrame(d.groupby("num of ratings")50)
D=d[d['num of ratings']>50]
D.head(50)
# Out:
#                                                     rating  num of ratings
# title
# 10 Things I Hate About You (1999)                      5.0              54
# 12 Angry Men (1957)                                    5.0              57
# 2001: A Space Odyssey (1968)                           5.0             109
# 28 Days Later (2002)                                   5.0              58
# 40-Year-Old Virgin, The (2005)                         5.0              74
# A.I. Artificial Intelligence (2001)                    5.0              56
# Addams Family Values (1993)                            5.0              84
# Air Force One (1997)                                   5.0              58
# Airplane! (1980)                                       5.0              87
# Aladdin (1992)                                         5.0             183
# Alien (1979)                                           5.0             146
# ...

# %%
D['num of ratings'].max()
# Out:
# 329

# %%
D['num of ratings'].mean()
# Out:
# 100.50819672131148

# %%
D['num of ratings'].min()
# Out:
# 51

# %%
links=pd.read_csv(r"C:\Users\KINGS\Downloads\movie_data\links.csv")

# %%
links.shape
# Out:
# (9742, 3)

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = 'https://www.imdb.com/'
response = requests.get(url)

# %%
response
# Out:
# <Response [403]>
